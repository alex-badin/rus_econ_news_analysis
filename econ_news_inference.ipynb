# %% [markdown]
# # INFERENCE
# - load news
# - select important ones (via model)
# - evaluate news - positive vs negative

# %% [markdown]
# ### constants and imports

# %%
# check env - google colab or local
import sys

def check_environment():
    if 'google.colab' in sys.modules:
        # Running in Google Colab
        return "Google Colab"

    if hasattr(sys, 'prefix'):
        if sys.prefix.startswith('/usr/local'):
            # Running in a Colab-like environment (could be Colab or another cloud environment)
            return "Colab-like environment"
        else:
            # Running in a local environment
            return "Local environment"

    # Default to local environment if checks are inconclusive
    return "Local environment"

# %%
# set paths and install packages depending on the environment

if check_environment() == 'Google Colab':
    # !pip install --quiet sentence_transformers transformers sumy nltk gnews newspaper3k

    from google.colab import drive
    drive.mount('/content/drive')

    path = '/content/drive/MyDrive/Colab Notebooks/other/econ_news(Kulbaka)/'

else:
    path = ''
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from gnews import GNews
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
import nltk
from sumy.summarizers.lsa import LsaSummarizer

import pandas as pd
import numpy as np
import pickle
from tqdm import tqdm
# Out:
# /usr/local/lib/python3.10/dist-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.17) or chardet (5.2.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %% [markdown]
# # Load news (incl full texts)

# %%
# set today's date
# date = pd.to_datetime('today').date()

# google_news = GNews(language='ru', country='RU', start_date=date - pd.Timedelta(days=1), end_date=date)
# today_news = google_news.get_news('Экономика России')

# %%
# download news day by day (due to 100 limit) via combining dictionaries
start_date = '2023-10-03'
end_date = '2023-10-10'

rus_econ_news = []
for date in tqdm(pd.date_range(start_date, end_date)):
    google_news = GNews(language='ru', country='RU', start_date=date - pd.Timedelta(days=1), end_date=date)
    rus_econ_news += google_news.get_news('Экономика России')
# Out:
# 100%|██████████| 8/8 [01:49<00:00, 13.68s/it]

# %%
# get full articles following the links
for news in tqdm(rus_econ_news):
    try:
        # get the full article
        news['full_article'] = google_news.get_full_article(news['url']).text
    except:
        news['full_article'] = ''
# Out:
#   1%|          | 5/717 [00:11<28:13,  2.38s/it]ERROR:gnews.gnews:Article `download()` failed with 403 Client Error: Forbidden for url: https://news.ru/dengi/ekonomist-predrek-dollar-vyshe-100-v-konce-oktyabrya/ on URL https://news.google.com/rss/articles/CBMiS2h0dHBzOi8vbmV3cy5ydS9kZW5naS9la29ub21pc3QtcHJlZHJlay1kb2xsYXItdnlzaGUtMTAwLXYta29uY2Utb2t0eWFicnlhL9IBT2h0dHBzOi8vbmV3cy5ydS9hbXAvZGVuZ2kvZWtvbm9taXN0LXByZWRyZWstZG9sbGFyLXZ5c2hlLTEwMC12LWtvbmNlLW9rdHlhYnJ5YS8?oc=5&hl=en-SG&gl=SG&ceid=SG:en
#   4%|▍         | 28/717 [01:01<31:41,  2.76s/it]ERROR:gnews.gnews:Article `download()` failed with HTTPSConnectionPool(host='www.mos.ru', port=443): Max retries exceeded with url: /news/item/130359073/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x78f5736d9d20>, 'Connection to www.mos.ru timed out. (connect timeout=7)')) on URL https://news.google.com/rss/articles/CBMiJ2h0dHBzOi8vd3d3Lm1vcy5ydS9uZXdzL2l0ZW0vMTMwMzU5MDczL9IBAA?oc=5&hl=en-SG&gl=SG&ceid=SG:en
#   4%|▍         | 29/717 [01:08<47:56,  4.18s/it]ERROR:gnews.gnews:Article `download()` failed with 403 Client Error: Forbidden for url: https://12-kanal.ru/news/184358/ on URL https://news.google.com/rss/articles/CBMiIGh0dHBzOi8vMTIta2FuYWwucnUvbmV3cy8xODQzNTgv0gEfaHR0cHM6Ly8xMi1rYW5hbC5ydS9hbXAvMTg0MzU4Lw?oc=5&hl=en-SG&gl=SG&ceid=SG:en
#   6%|▌         | 43/717 [01:41<27:01,  2.41s/it]ERROR:gnews.gnews:Article `download()` failed with HTTPSConnectionPool(host
/it]ERROR:gnews.gnews:Article `download()` failed with 403 Client Error: Forbidden for url: https://astv.ru/news/society/2023-10-08-rossiyane-vyskazalis-za-zhestkie-shtrafy-dlya-p-yanyh-voditelej-elektrosamokatov on URL https://news.google.com/rss/articles/CBMieGh0dHBzOi8vYXN0di5ydS9uZXdzL3NvY2lldHkvMjAyMy0xMC0wOC1yb3NzaXlhbmUtdnlza2F6YWxpcy16YS16aGVzdGtpZS1zaHRyYWZ5LWRseWEtcC15YW55aC12b2RpdGVsZWotZWxla3Ryb3NhbW9rYXRvdtIBAA?oc=5&hl=en-SG&gl=SG&ceid=SG:en
#  88%|████████▊ | 629/717 [21:43<02:26,  1.67s/it]ERROR:gnews.gnews:Article `download()` failed with 403 Client Error: Forbidden for url: https://www.unian.net/economics/finance/ekonomika-rf-okazalas-gorazdo-bolee-ustoychivoy-k-sankciyam-chem-dumali-na-zapade-nyt-12419931.html on URL https://news.google....?oc=5&hl=en-SG&gl=SG&ceid=SG:en
#  91%|█████████ | 653/717 [22:31<02:09,  2.03s/it]ERROR:gnews.gnews:Article `download()` failed with 403 Client Error: Forbidden for url: https://news.ru/press-relizy/shkolnikam-rasskazali-kak-kruto-i-modno-byt-professionalom/ on URL https://news.google.com/rss/articles/CBMiWGh0dHBzOi8vbmV3cy5ydS9wcmVzcy1yZWxpenkvc2hrb2xuaWthbS1yYXNza2F6YWxpLWthay1rcnV0by1pLW1vZG5vLWJ5dC1wcm9mZXNzaW9uYWxvbS_SAVxodHRwczovL25ld3MucnUvYW1wL3ByZXNzLXJlbGl6eS9zaGtvbG5pa2FtLXJhc3NrYXphbGkta2FrLWtydXRvLWktbW9kbm8tYnl0LXByb2Zlc3Npb25hbG9tLw?oc=5&hl=en-SG&gl=SG&ceid=SG:en
#  98%|█████████▊| 704/717 [24:08<00:26,  2.04s/it]ERROR:gnews.gnews:Article `download()` failed with 403 Client Error: Forbidden for url: https://76.ru/text/world/2023/10/09/72786752/ on URL https://news.google.com/rss/articles/CBMiLWh0dHBzOi8vNzYucnUvdGV4dC93b3JsZC8yMDIzLzEwLzA5LzcyNzg2NzUyL9IBAA?oc=5&hl=en-SG&gl=SG&ceid=SG:en
# 100%|██████████| 717/717 [24:31<00:00,  2.05s/it]

# %%
with open(path+'rus_econ_news.pkl', 'wb') as f:
    pickle.dump(rus_econ_news, f)

# %%
# summarize the news (select 2 most important sentences)
summarizer_2 = LsaSummarizer()
nltk.download('punkt')

def summarize(text, language="english", sentences_count=5):
    parser = PlaintextParser.from_string(text, Tokenizer(language))
    summarizer = LsaSummarizer()
    summary = summarizer(parser.document, sentences_count)
    return ' '.join([str(sentence) for sentence in summary])

# iterate over news
for news in tqdm(rus_econ_news):
    try:
        news['summary'] = summarize(news['full_article'], language="russian", sentences_count=2)
    except:
        news['summary'] = ''
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 100%|██████████| 717/717 [00:54<00:00, 13.25it/s]

# %%
last_news = pd.DataFrame(rus_econ_news)
# replace missing articles with descriptions
last_news['full_article'].fillna(last_news['description'], inplace=True)
last_news['summary'].fillna(last_news['description'], inplace=True)

# %%
last_news.to_csv(path+'last_news.csv')

# %% [markdown]
# ## Select important news
# - embeddings
# - predict importance

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('intfloat/multilingual-e5-large')

# %%
# embed the news
texts = last_news['summary'].to_list()
embeddings = model.encode(texts, show_progress_bar=True)

last_news["emb_e5"] = [row.reshape(-1) for row in embeddings]
# Out:
# Batches:   0%|          | 0/23 [00:00<?, ?it/s]

# %%
# predict the importance
clf = pickle.load(open(path+'news_importance_model.pkl', 'rb'))
last_news['prob_import'] = clf.predict_proba(embeddings)[:,1]
# mark the news with prob > 0.38 as important
last_news['important'] = np.where(last_news['prob_import'] > 0.38, 1, 0)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator LogisticRegression from version 1.3.1 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# <ipython-input-13-c581d6f00152>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_news[last_news['prob_import'] > .38]['important'] = 1

# %%
last_news.to_csv(path+'last_news.csv')

# %%
last_news.important.sum(), last_news.important.count()
# Out:
# (36, 717)

# %% [markdown]
# # Evaluate news

# %%
from transformers import pipeline
classifier = pipeline("zero-shot-classification", model="MoritzLaurer/mDeBERTa-v3-base-mnli-xnli")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:473: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
last_imp_news = last_news[last_news.important==1]

# %%
# NLI fr imprt news. Candidate labels can be adjusted
bad_news = ['плохо для российской экономики', 'российская экономика ухудшается', 'негативная новость для экономики России']
good_news = ['хорошо для российской экономики', 'российская экономика  улучшается', 'позитивная новость для экономики России']
candidate_labels = bad_news + good_news
n_labels = len(candidate_labels)

for id, row in tqdm(last_imp_news.iterrows(), total = last_news[last_news.important==1].shape[0]):
    output = classifier(row['summary'], candidate_labels, multi_label=True)
    for i_label in range(n_labels):
      last_imp_news.at[id, output['labels'][i_label]] = output['scores'][i_label]
# Out:
# 100%|██████████| 36/36 [01:53<00:00,  3.16s/it]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-cd636a38aea5> in <cell line: 7>()
#       6
#       7 for id, row in tqdm(last_imp_news.iterrows(), total = last_news[last_news.important==1].shape[0]):
# ----> 8     output = classifier(row['summary'], candidate_labels, multi_label=True)
#       9     for i_label in range(n_labels):
#      10       last_imp_news.at[id, output['labels'][i_label]] = output['scores'][i_label]
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/zero_shot_classification.py in __call__(self, sequences, *args, **kwargs)
#     204             raise ValueError(f"Unable to understand extra arguments {args}")
#     205
# --> 206         return super().__call__(sequences, **kwargs)
#     207
#     208     def preprocess(self, inputs, candidate_labels=None, hypothesis_template="This example is {}."):
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1130             return self.iterate(inputs, preprocess_params, forward_params, postprocess_params)
#    1131         elif self.framework == "pt" and isinstance(self, ChunkPipeline):
# -> 1132             return next(
#    1133                 iter(
#    1134                     self.get_iterator(
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     122
#     123         # We're out of items within a batch
# --> 124         item = next(self.iterator)
#     125         processed = self.infer(item, **self.params)
#     126         # We now have a batch of "inferred things".
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     264
#     265         while not is_last:
# --> 266             processed = self.infer(next(self.iterator), **self.params)
#     267             if self.loader_batch_size is not None:
#     268                 if isinstance(processed, torch.Tensor):
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     631                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     632                 self._reset()  # type: ignore[call-arg]
# --> 633             data = self._next_data()
#     634             self._num_yielded += 1
#     635             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     675     def _next_data(self):
#     676         index = self._next_index()  # may raise StopIteration
# --> 677         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     678         if self._pin_memory:
#     679             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      30             for _ in possibly_batched_index:
#      31                 try:
# ---> 32                     data.append(next(self.dataset_iter))
#      33                 except StopIteration:
#      34                     self.ended = True
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     181         try:
#     182             # Try to return next item
# --> 183             processed = next(self.subiterator)
#     184         except StopIteration:
#     185             # When a preprocess iterator ends, we can start lookig at the next item
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/zero_shot_classification.py in preprocess(self, inputs, candidate_labels, hypothesis_template)
#     207
#     208     def preprocess(self, inputs, candidate_labels=None, hypothesis_template="This example is {}."):
# --> 209         sequence_pairs, sequences = self._args_parser(inputs, candidate_labels, hypothesis_template)
#     210
#     211         for i, (candidate_label, sequence_pair) in enumerate(zip(candidate_labels, sequence_pairs)):
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/zero_shot_classification.py in __call__(self, sequences, labels, hypothesis_template)
#      24
#      25     def __call__(self, sequences, labels, hypothesis_template):
# ---> 26         if len(labels) == 0 or len(sequences) == 0:
#      27             raise ValueError("You must include at least one label and at least one sequence.")
#      28         if hypothesis_template.format(labels[0]) == hypothesis_template:
#
# TypeError: object of type 'float' has no len()

# %%
last_imp_news['bad_news'] = last_imp_news[bad_news].mean(axis=1)
last_imp_news['good_news'] = last_imp_news[good_news].mean(axis=1)

# %%
last_imp_news.to_csv(path+'last_imp_news.csv')

# %%
last_imp_news = pd.read_csv(path+'last_imp_news.csv')

# %%
last_imp_news[['published date','summary', 'prob_import', 'bad_news', 'good_news']].sort_values('bad_news', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aff0ed74cb3d> in <cell line: 1>()
# ----> 1 last_imp_news[['published date','summary', 'prob_import', 'bad_news', 'good_news']].sort_values('bad_news', ascending=False)
#
# NameError: name 'last_imp_news' is not defined
